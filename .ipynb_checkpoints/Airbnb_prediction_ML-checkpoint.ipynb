# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Data is from Kaggle.com: https://www.kaggle.com/rudymizrahi/airbnb-listings-in-major-us-cities-deloitte-ml
#
#
#
# ## Features
# 1. id: Record identifier
# 2. log_price: log(price) [ the logarithm used is natural log]
# 3. ... : 25 features for the listing
#
# ## Evaluation
# the evaluation metric for the competitoin is the Root Mean Squared Error (RMSE) score

# %%
bnb_df = pd.read_csv("Data/train.csv")

# %%
bnb_df.head()
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...   latitude   longitude  \
# 0  Real Bed              strict          True  ...  40.696524  -73.991617
# 1  Real Bed              strict          True  ...  40.766115  -73.989040
# 2  Real Bed            moderate          True  ...  40.808110  -73.943756
# 3  Real Bed            flexible          True  ...  37.772004 -122.431619
# 4  Real Bed            moderate          True  ...  38.925627  -77.034596
#
#                                        name     neighbourhood  \
# 0            Beautiful brownstone 1-bedroom  Brooklyn Heights
# 1  Superb 3BR Apt Located Near Times Square    Hell's Kitchen
# 2                          The Garden Oasis            Harlem
# 3        Beautiful Flat in the Heart of SF!      Lower Haight
# 4                Great studio in midtown DC  Columbia Heights
#
#   number_of_reviews review_scores_rating  \
# 0                 2                100.0
# 1                 6                 93.0
# 2                10                 92.0
# 3                 0                  NaN
# 4                 4                 40.0
#
#                                        thumbnail_url  zipcode bedrooms  beds
# 0  https://a0.muscache.com/im/pictures/6d7cbbf7-c...    11201      1.0   1.0
# 1  https://a0.muscache.com/im/pictures/348a55fe-4...    10019      3.0   3.0
# 2  https://a0.muscache.com/im/pictures/6fae5362-9...    10027      1.0   3.0
# 3  https://a0.muscache.com/im/pictures/72208dad-9...  94117.0      2.0   2.0
# 4                                                NaN    20009      0.0   1.0
#
# [5 rows x 29 columns]

# %%
bnb_df.shape
# Out:
# (74111, 29)

# %% [markdown]
# ## Data Exploration (exploratory data analysis or EDA)
#
# The goal here is to find out more about the data and become a subject matter expert on the dataset you're working with.
#
# Short checklist to keep in mind:
#
# 1. What question(s) are you trying to solve?
#
# create a model that predicts the variable "log_price"
#
# 2. What kind of data do we have and how do we treat different types?
# 3. What's missing from the data and how do you deal with it?
# 4. Where are the outliers and why should you care about them?
# 5. How can you add, change or remove features to get more out of your data?

# %%
bnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      74111 non-null  int64
#  1   log_price               74111 non-null  float64
#  2   property_type           74111 non-null  object
#  3   room_type               74111 non-null  object
#  4   amenities               74111 non-null  object
#  5   accommodates            74111 non-null  int64
#  6   bathrooms               73911 non-null  float64
#  7   bed_type                74111 non-null  object
#  8   cancellation_policy     74111 non-null  object
#  9   cleaning_fee            74111 non-null  bool
#  10  city                    74111 non-null  object
#  11  description             74111 non-null  object
#  12  first_review            58247 non-null  object
#  13  host_has_profile_pic    73923 non-null  object
#  14  host_identity_verified  73923 non-null  object
#  15  host_response_rate      55812 non-null  object
#  16  host_since              73923 non-null  object
#  17  instant_bookable        74111 non-null  object
#  18  last_review             58284 non-null  object
#  19  latitude                74111 non-null  float64
#  20  longitude               74111 non-null  float64
#  21  name                    74111 non-null  object
#  22  neighbourhood           67239 non-null  object
#  23  number_of_reviews       74111 non-null  int64
#  24  review_scores_rating    57389 non-null  float64
#  25  thumbnail_url           65895 non-null  object
#  26  zipcode                 73145 non-null  object
#  27  bedrooms                74020 non-null  float64
#  28  beds                    73980 non-null  float64
# dtypes: bool(1), float64(7), int64(3), object(18)
# memory usage: 15.9+ MB

# %%
# check for null values
bnb_df.isnull().sum()
# Out:
# id                            0
# log_price                     0
# property_type                 0
# room_type                     0
# amenities                     0
# accommodates                  0
# bathrooms                   200
# bed_type                      0
# cancellation_policy           0
# cleaning_fee                  0
# city                          0
# description                   0
# first_review              15864
# host_has_profile_pic        188
# host_identity_verified      188
# host_response_rate        18299
# host_since                  188
# instant_bookable              0
# last_review               15827
# latitude                      0
# longitude                     0
# name                          0
# neighbourhood              6872
# number_of_reviews             0
# review_scores_rating      16722
# thumbnail_url              8216
# zipcode                     966
# bedrooms                     91
# beds                        131
# dtype: int64

# %%
bnb_df.describe()
# Out:
#                  id     log_price  accommodates     bathrooms      latitude  \
# count  7.411100e+04  74111.000000  74111.000000  73911.000000  74111.000000
# mean   1.126662e+07      4.782069      3.155146      1.235263     38.445958
# std    6.081735e+06      0.717394      2.153589      0.582044      3.080167
# min    3.440000e+02      0.000000      1.000000      0.000000     33.338905
# 25%    6.261964e+06      4.317488      2.000000      1.000000     34.127908
# 50%    1.225415e+07      4.709530      2.000000      1.000000     40.662138
# 75%    1.640226e+07      5.220356      4.000000      1.000000     40.746096
# max    2.123090e+07      7.600402     16.000000      8.000000     42.390437
#
#           longitude  number_of_reviews  review_scores_rating      bedrooms  \
# count  74111.000000       74111.000000          57389.000000  74020.000000
# mean     -92.397525          20.900568             94.067365      1.265793
# std       21.705322          37.828641              7.836556      0.852143
# min     -122.511500           0.000000             20.000000      0.000000
# 25%     -118.342374           1.000000             92.000000      1.000000
# 50%      -76.996965           6.000000             96.000000      1.000000
# 75%      -73.954660          23.000000            100.000000      1.000000
# max      -70.985047         605.000000            100.000000     10.000000
#
#                beds
# count  73980.000000
# mean       1.710868
# std        1.254142
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max       18.000000

# %%
bnb_df['accommodates'].value_counts()
# Out:
# 2     31854
# 4     12066
# 1      9434
# 3      7794
# 6      4969
# 5      3444
# 8      1795
# 7       946
# 10      701
# 16      301
# 9       270
# 12      264
# 14      104
# 11       79
# 15       54
# 13       36
# Name: accommodates, dtype: int64

# %%
bnb_df.corr()
# Out:
#                             id  log_price  accommodates  bathrooms  \
# id                    1.000000  -0.007178     -0.005759  -0.003951
# log_price            -0.007178   1.000000      0.567574   0.355420
# accommodates         -0.005759   0.567574      1.000000   0.505632
# bathrooms            -0.003951   0.355420      0.505632   1.000000
# cleaning_fee         -0.003059   0.111191      0.182306   0.053784
# latitude             -0.003021  -0.002193     -0.078309  -0.137959
# longitude            -0.001379  -0.047529     -0.085160  -0.135026
# number_of_reviews     0.002945  -0.032470      0.041964  -0.041381
# review_scores_rating  0.000307   0.091219     -0.017128   0.010537
# bedrooms             -0.007521   0.473212      0.709258   0.589935
# beds                 -0.008665   0.442153      0.810801   0.525591
#
#                       cleaning_fee  latitude  longitude  number_of_reviews  \
# id                       -0.003059 -0.003021  -0.001379           0.002945
# log_price                 0.111191 -0.002193  -0.047529          -0.032470
# accommodates              0.182306 -0.078309  -0.085160           0.041964
# bathrooms                 0.053784 -0.137959  -0.135026          -0.041381
# cleaning_fee              1.000000 -0.060913  -0.068505           0.110204
# latitude                 -0.060913  1.000000   0.896065          -0.017642
# longitude                -0.068505  0.896065   1.000000          -0.050009
# number_of_reviews         0.110204 -0.017642  -0.050009           1.000000
# review_scores_rating      0.034879 -0.032858  -0.048801           0.011708
# bedrooms                  0.105454 -0.059162  -0.076113          -0.035149
# beds                      0.131632 -0.080294  -0.082150           0.031109
#
#                       review_scores_rating  bedrooms      beds
# id                                0.000307 -0.007521 -0.008665
# log_price                         0.091219  0.473212  0.442153
# accommodates                     -0.017128  0.709258  0.810801
# bathrooms                         0.010537  0.589935  0.525591
# cleaning_fee                      0.034879  0.105454  0.131632
# latitude                         -0.032858 -0.059162 -0.080294
# longitude                        -0.048801 -0.076113 -0.082150
# number_of_reviews                 0.011708 -0.035149  0.031109
# review_scores_rating              1.000000  0.011143 -0.027330
# bedrooms                          0.011143  1.000000  0.709416
# beds                             -0.027330  0.709416  1.000000

# %%
# create a function that graphs sns correlation heatmap
def sns_corr_heatmap(df):
    corr_matrix = df.corr()
    plt.figure(figsize=(15,12))
    sns.heatmap(corr_matrix,
               annot=True,
               fmt='.2f',
               cmap="Blues")

# %%
# Create a correlation matrix using seaborn's heatmap
sns_corr_heatmap(bnb_df)

# %%
# compare accommodates with the log price (target variable)
plt.scatter(bnb_df['accommodates'], bnb_df['log_price'])
plt.xlabel("Accommodates")
plt.ylabel("Log Price")
# Out:
# Text(0, 0.5, 'Log Price')

# %%
bnb_df.columns
# Out:
# Index(['id', 'log_price', 'property_type', 'room_type', 'amenities',
#        'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy',
#        'cleaning_fee', 'city', 'description', 'first_review',
#        'host_has_profile_pic', 'host_identity_verified', 'host_response_rate',
#        'host_since', 'instant_bookable', 'last_review', 'latitude',
#        'longitude', 'name', 'neighbourhood', 'number_of_reviews',
#        'review_scores_rating', 'thumbnail_url', 'zipcode', 'bedrooms', 'beds'],
#       dtype='object')

# %%
bnb_df['bedrooms'].value_counts()
# Out:
# 1.0     49784
# 2.0     11351
# 0.0      6715
# 3.0      4309
# 4.0      1330
# 5.0       355
# 6.0       106
# 7.0        38
# 8.0        14
# 10.0       10
# 9.0         8
# Name: bedrooms, dtype: int64

# %%
bnb_df['bedrooms'].plot(kind='hist')

# %%
# compare bedrooms with log_price
bnb_df['bedrooms'].value_counts().plot(kind="bar")

# %%
bnb_df.head(2).T
# Out:
#                                                                         0  \
# id                                                                6901257
# log_price                                                         5.01064
# property_type                                                   Apartment
# room_type                                                 Entire home/apt
# amenities               {"Wireless Internet","Air conditioning",Kitche...
# accommodates                                                            3
# bathrooms                                                               1
# bed_type                                                         Real Bed
# cancellation_policy                                                strict
# cleaning_fee                                                         True
# city                                                                  NYC
# description             Beautiful, sunlit brownstone 1-bedroom in the ...
# first_review                                                   2016-06-18
# host_has_profile_pic                                                    t
# host_identity_verified                                                  t
# host_response_rate                                                    NaN
# host_since                                                     2012-03-26
# instant_bookable                                                        f
# last_review                                                    2016-07-18
# latitude                                                          40.6965
# longitude                                                        -73.9916
# name                                       Beautiful brownstone 1-bedroom
# neighbourhood                                            Brooklyn Heights
# number_of_reviews                                                       2
# review_scores_rating                                                  100
# thumbnail_url           https://a0.muscache.com/im/pictures/6d7cbbf7-c...
# zipcode                                                             11201
# bedrooms                                                                1
# beds                                                                    1
#
#                                                                         1
# id                                                                6304928
# log_price                                                          5.1299
# property_type                                                   Apartment
# room_type                                                 Entire home/apt
# amenities               {"Wireless Internet","Air conditioning",Kitche...
# accommodates                                                            7
# bathrooms                                                               1
# bed_type                                                         Real Bed
# cancellation_policy                                                strict
# cleaning_fee                                                         True
# city                                                                  NYC
# description             Enjoy travelling during your stay in Manhattan...
# first_review                                                   2017-08-05
# host_has_profile_pic                                                    t
# host_identity_verified                                                  f
# host_response_rate                                                   100%
# host_since                                                     2017-06-19
# instant_bookable                                                        t
# last_review                                                    2017-09-23
# latitude                                                          40.7661
# longitude                                                         -73.989
# name                             Superb 3BR Apt Located Near Times Square
# neighbourhood                                              Hell's Kitchen
# number_of_reviews                                                       6
# review_scores_rating                                                   93
# thumbnail_url           https://a0.muscache.com/im/pictures/348a55fe-4...
# zipcode                                                             10019
# bedrooms                                                                3
# beds                                                                    3

# %%
# convert log price to unit price
bnb_df['int_price'] = np.exp(bnb_df['log_price'])

# %%
# sort dataset by host_since
bnb_df.sort_values(by='host_since')['host_since'].head()
# Out:
# 72898    2008-03-03
# 48876    2008-03-04
# 24742    2008-04-21
# 68396    2008-06-27
# 7461     2008-07-11
# Name: host_since, dtype: object

# %%
bnb_df.dtypes
# Out:
# id                          int64
# log_price                 float64
# property_type              object
# room_type                  object
# amenities                  object
# accommodates                int64
# bathrooms                 float64
# bed_type                   object
# cancellation_policy        object
# cleaning_fee                 bool
# city                       object
# description                object
# first_review               object
# host_has_profile_pic       object
# host_identity_verified     object
# host_response_rate         object
# host_since                 object
# instant_bookable           object
# last_review                object
# latitude                  float64
# longitude                 float64
# name                       object
# neighbourhood              object
# number_of_reviews           int64
# review_scores_rating      float64
# thumbnail_url              object
# zipcode                    object
# bedrooms                  float64
# beds                      float64
# int_price                 float64
# dtype: object

# %%
bnb_df['host_since'] = pd.to_datetime(bnb_df['host_since'])
bnb_df['last_review'] = pd.to_datetime(bnb_df['last_review'])
bnb_df['first_review'] = pd.to_datetime(bnb_df['first_review'])

# %%
bnb_df.dtypes
# Out:
# id                                 int64
# log_price                        float64
# property_type                     object
# room_type                         object
# amenities                         object
# accommodates                       int64
# bathrooms                        float64
# bed_type                          object
# cancellation_policy               object
# cleaning_fee                        bool
# city                              object
# description                       object
# first_review                      object
# host_has_profile_pic              object
# host_identity_verified            object
# host_response_rate                object
# host_since                datetime64[ns]
# instant_bookable                  object
# last_review               datetime64[ns]
# latitude                         float64
# longitude                        float64
# name                              object
# neighbourhood                     object
# number_of_reviews                  int64
# review_scores_rating             float64
# thumbnail_url                     object
# zipcode                           object
# bedrooms                         float64
# beds                             float64
# int_price                        float64
# dtype: object

# %%
bnb_df['host_since'].dt.month
# Out:
# 0         3.0
# 1         6.0
# 2        10.0
# 3         4.0
# 4         3.0
#          ...
# 74106     3.0
# 74107     5.0
# 74108     1.0
# 74109     9.0
# 74110    11.0
# Name: host_since, Length: 74111, dtype: float64

# %% [markdown]
# #### converting string columns into numerical values
#
#
# https://pandas.pydata.org/pandas-docs/version/0.25.3/reference/general_utility_functions.html#data-types-related-functionality
#
#
# turn into categories to access all data in the form of numbers

# %%
# Test codes
pd.api.types.is_object_dtype(bnb_df['city'])
# Out:
# True

# %%
bnb_df.head()
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...   longitude  \
# 0  Real Bed              strict          True  ...  -73.991617
# 1  Real Bed              strict          True  ...  -73.989040
# 2  Real Bed            moderate          True  ...  -73.943756
# 3  Real Bed            flexible          True  ... -122.431619
# 4  Real Bed            moderate          True  ...  -77.034596
#
#                                        name     neighbourhood  \
# 0            Beautiful brownstone 1-bedroom  Brooklyn Heights
# 1  Superb 3BR Apt Located Near Times Square    Hell's Kitchen
# 2                          The Garden Oasis            Harlem
# 3        Beautiful Flat in the Heart of SF!      Lower Haight
# 4                Great studio in midtown DC  Columbia Heights
#
#   number_of_reviews review_scores_rating  \
# 0                 2                100.0
# 1                 6                 93.0
# 2                10                 92.0
# 3                 0                  NaN
# 4                 4                 40.0
#
#                                        thumbnail_url  zipcode bedrooms beds  \
# 0  https://a0.muscache.com/im/pictures/6d7cbbf7-c...    11201      1.0  1.0
# 1  https://a0.muscache.com/im/pictures/348a55fe-4...    10019      3.0  3.0
# 2  https://a0.muscache.com/im/pictures/6fae5362-9...    10027      1.0  3.0
# 3  https://a0.muscache.com/im/pictures/72208dad-9...  94117.0      2.0  2.0
# 4                                                NaN    20009      0.0  1.0
#
#    int_price
# 0      150.0
# 1      169.0
# 2      145.0
# 3      750.0
# 4      115.0
#
# [5 rows x 30 columns]

# %%
for label, content in bnb_df.items():
    if pd.api.types.is_object_dtype(bnb_df[label]):
        # print(label)
        bnb_df[label] = content.astype('category').cat.as_ordered()

# %%
# check if changes are made
bnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      74111 non-null  int64
#  1   log_price               74111 non-null  float64
#  2   property_type           74111 non-null  category
#  3   room_type               74111 non-null  category
#  4   amenities               74111 non-null  category
#  5   accommodates            74111 non-null  int64
#  6   bathrooms               73911 non-null  float64
#  7   bed_type                74111 non-null  category
#  8   cancellation_policy     74111 non-null  category
#  9   cleaning_fee            74111 non-null  bool
#  10  city                    74111 non-null  category
#  11  description             74111 non-null  category
#  12  first_review            58247 non-null  category
#  13  host_has_profile_pic    73923 non-null  category
#  14  host_identity_verified  73923 non-null  category
#  15  host_response_rate      55812 non-null  category
#  16  host_since              73923 non-null  datetime64[ns]
#  17  instant_bookable        74111 non-null  category
#  18  last_review             58284 non-null  datetime64[ns]
#  19  latitude                74111 non-null  float64
#  20  longitude               74111 non-null  float64
#  21  name                    74111 non-null  category
#  22  neighbourhood           67239 non-null  category
#  23  number_of_reviews       74111 non-null  int64
#  24  review_scores_rating    57389 non-null  float64
#  25  thumbnail_url           65895 non-null  category
#  26  zipcode                 73145 non-null  category
#  27  bedrooms                74020 non-null  float64
#  28  beds                    73980 non-null  float64
#  29  int_price               74111 non-null  float64
# dtypes: bool(1), category(16), datetime64[ns](2), float64(8), int64(3)
# memory usage: 21.9 MB

# %%
bnb_df['neighbourhood'].cat.categories
# Out:
# Index(['16th Street Heights', 'Adams Morgan', 'Alamo Square', 'Albany Park',
#        'Alhambra', 'Allerton', 'Allston-Brighton', 'Alondra Park',
#        'Alphabet City', 'Altadena',
#        ...
#        'Winnetka', 'Winthrop', 'Woodhaven', 'Woodland',
#        'Woodland Hills/Warner Center', 'Woodlawn', 'Woodley Park', 'Woodridge',
#        'Woodside', 'Wrigleyville'],
#       dtype='object', length=619)

# %%
bnb_df['neighbourhood'].cat.codes
# Out:
# 0         77
# 1        252
# 2        247
# 3        325
# 4        119
#         ...
# 74106    605
# 74107    255
# 74108    605
# 74109    592
# 74110    319
# Length: 74111, dtype: int16

# %%
print(bnb_df['neighbourhood'].nunique())
print(bnb_df['neighbourhood'].cat.codes.nunique())
# Out:
# 619
# 620

# %%
# check over dataset again
bnb_df.head(2).T
# Out:
#                                                                         0  \
# id                                                                6901257
# log_price                                                         5.01064
# property_type                                                   Apartment
# room_type                                                 Entire home/apt
# amenities               {"Wireless Internet","Air conditioning",Kitche...
# accommodates                                                            3
# bathrooms                                                               1
# bed_type                                                         Real Bed
# cancellation_policy                                                strict
# cleaning_fee                                                         True
# city                                                                  NYC
# description             Beautiful, sunlit brownstone 1-bedroom in the ...
# first_review                                                   2016-06-18
# host_has_profile_pic                                                    t
# host_identity_verified                                                  t
# host_response_rate                                                    NaN
# host_since                                            2012-03-26 00:00:00
# instant_bookable                                                        f
# last_review                                           2016-07-18 00:00:00
# latitude                                                          40.6965
# longitude                                                        -73.9916
# name                                       Beautiful brownstone 1-bedroom
# neighbourhood                                            Brooklyn Heights
# number_of_reviews                                                       2
# review_scores_rating                                                  100
# thumbnail_url           https://a0.muscache.com/im/pictures/6d7cbbf7-c...
# zipcode                                                             11201
# bedrooms                                                                1
# beds                                                                    1
# int_price                                                             150
#
#                                                                         1
# id                                                                6304928
# log_price                                                          5.1299
# property_type                                                   Apartment
# room_type                                                 Entire home/apt
# amenities               {"Wireless Internet","Air conditioning",Kitche...
# accommodates                                                            7
# bathrooms                                                               1
# bed_type                                                         Real Bed
# cancellation_policy                                                strict
# cleaning_fee                                                         True
# city                                                                  NYC
# description             Enjoy travelling during your stay in Manhattan...
# first_review                                                   2017-08-05
# host_has_profile_pic                                                    t
# host_identity_verified                                                  f
# host_response_rate                                                   100%
# host_since                                            2017-06-19 00:00:00
# instant_bookable                                                        t
# last_review                                           2017-09-23 00:00:00
# latitude                                                          40.7661
# longitude                                                         -73.989
# name                             Superb 3BR Apt Located Near Times Square
# neighbourhood                                              Hell's Kitchen
# number_of_reviews                                                       6
# review_scores_rating                                                   93
# thumbnail_url           https://a0.muscache.com/im/pictures/348a55fe-4...
# zipcode                                                             10019
# bedrooms                                                                3
# beds                                                                    3
# int_price                                                             169

# %% [markdown]
# #### Find the missing zipcodes using its lat and long values

# %%
# !pip install uszipcode
# Out:
# Collecting uszipcode
#   Downloading uszipcode-0.2.4-py2.py3-none-any.whl (378 kB)
# Requirement already satisfied: attrs in c:\users\smartestpersonalive\anaconda3\lib\site-packages (from uszipcode) (19.3.0)
# Collecting pathlib-mate
#   Downloading pathlib_mate-1.0.1-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: sqlalchemy in c:\users\smartestpersonalive\anaconda3\lib\site-packages (from uszipcode) (1.3.9)
# Requirement already satisfied: requests in c:\users\smartestpersonalive\anaconda3\lib\site-packages (from uszipcode) (2.24.0)
# Requirement already satisfied: atomicwrites in c:\users\smartestpersonalive\anaconda3\lib\site-packages (from pathlib-mate->uszipcode) (1.4.0)
# Requirement already satisfied: six in c:\users\smartestpersonalive\anaconda3\lib\site-packages (from pathlib-mate->uszipcode) (1.15.0)
# Requirement already satisfied: autopep8 in c:\users\smartestpersonalive\anaconda3\lib\site-packages (from pathlib-mate->uszipcode) (1.5.3)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\smartestpersonalive\anaconda3\lib\site-packages (from requests->uszipcode) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\smartestpersonalive\anaconda3\lib\site-packages (from requests->uszipcode) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\smartestpersonalive\anaconda3\lib\site-packages (from requests->uszipcode) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\smartestpersonalive\anaconda3\lib\site-packages (from requests->uszipcode) (1.25.10)
# Requirement already satisfied: pycodestyle>=2.6.0 in c:\users\smartestpersonalive\anaconda3\lib\site-packages (from autopep8->pathlib-mate->uszipcode) (2.6.0)
# Requirement already satisfied: toml in c:\users\smartestpersonalive\anaconda3\lib\site-packages (from autopep8->pathlib-mate->uszipcode) (0.10.1)
# Installing collected packages: pathlib-mate, uszipcode
# Successfully installed pathlib-mate-1.0.1 uszipcode-0.2.4
# WARNING: You are using pip version 20.2.2; however, version 21.0 is available.
# You should consider upgrading via the 'c:\users\smartestpersonalive\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
from uszipcode import Zipcode, SearchEngine
search = SearchEngine(simple_zipcode=True)

# %%
bnb_df['zipcode'].isnull().sum()
# Out:
# 966

# %%
# make a copy
bnb_df1 = bnb_df.copy()

# %%
bnb_df[bnb_df1['zipcode'].isnull()]
# Out:
#              id  log_price property_type        room_type  \
# 26     19407360   4.553877     Apartment  Entire home/apt
# 96      4576821   4.248495     Apartment  Entire home/apt
# 189     7144212   4.828314     Apartment     Private room
# 401    19839317   7.569412         Villa  Entire home/apt
# 497    11742647   3.891820     Apartment     Private room
# ...         ...        ...           ...              ...
# 73642  13465498   3.761200     Apartment     Private room
# 73763  17300316   4.174387         House     Private room
# 73925  10575811   5.010635         House  Entire home/apt
# 74060  19102281   5.075174     Apartment     Private room
# 74083  15423281   5.010635     Apartment     Private room
#
#                                                amenities  accommodates  \
# 26     {TV,"Wireless Internet",Pool,Kitchen,"Elevator...             2
# 96     {"Wireless Internet",Kitchen,Breakfast,Elevato...             1
# 189    {TV,"Cable TV",Internet,"Wireless Internet","A...             1
# 401    {TV,"Cable TV",Internet,"Wireless Internet","A...             8
# 497    {TV,"Cable TV",Internet,"Wireless Internet","A...             2
# ...                                                  ...           ...
# 73642  {TV,"Cable TV",Internet,"Wireless Internet","A...             1
# 73763  {TV,"Wireless Internet","Air conditioning",Kit...             2
# 73925  {TV,"Wireless Internet","Air conditioning","Wh...             6
# 74060  {"Wireless Internet","Air conditioning",Kitche...             2
# 74083  {TV,"Wireless Internet",Kitchen,"Smoke detecto...             2
#
#        bathrooms  bed_type cancellation_policy  cleaning_fee  ...   longitude  \
# 26           1.0  Real Bed            flexible          True  ... -118.364204
# 96           1.0  Real Bed            flexible          True  ...  -73.977079
# 189          1.0  Real Bed              strict          True  ...  -74.007225
# 401          3.5  Real Bed     super_strict_60          True  ... -118.373981
# 497          1.0  Real Bed            flexible          True  ...  -73.913570
# ...          ...       ...                 ...           ...  ...         ...
# 73642        1.0  Real Bed              strict         False  ...  -73.911694
# 73763        1.0     Futon            flexible          True  ...  -76.987303
# 73925        1.0  Real Bed            flexible          True  ... -118.150099
# 74060        1.0  Real Bed            moderate          True  ...  -73.986541
# 74083        1.0  Real Bed            flexible         False  ... -122.423192
#
#                                                 name       neighbourhood  \
# 26               Retro West Hollywood Studio + Pool!                 NaN
# 96                     Charming Studio in Park Slope          Park Slope
# 189            Private room in Amazing Lux building!  Financial District
# 401                            Modern Luxury: 116852                 NaN
# 497                  Good Living in Brooklyn! Dbl Rm            Bushwick
# ...                                              ...                 ...
# 73642       Location Little Marina ( only for girls)             Astoria
# 73763       Private Room! Bike to Share! Cat to Pet!                 NaN
# 73925                              Delightful Duplex                 NaN
# 74060                     Cosy 1 bdr in Midtown West      Hell's Kitchen
# 74083  Charming bedroom in the heart of Russian Hill        Russian Hill
#
#       number_of_reviews review_scores_rating  \
# 26                    1                100.0
# 96                    2                100.0
# 189                   3                100.0
# 401                   1                100.0
# 497                  66                 96.0
# ...                 ...                  ...
# 73642                 3                 93.0
# 73763                 1                100.0
# 73925                19                 99.0
# 74060                10                 96.0
# 74083                 0                  NaN
#
#                                            thumbnail_url zipcode bedrooms  \
# 26     https://a0.muscache.com/im/pictures/c67ecdec-a...     NaN      1.0
# 96     https://a0.muscache.com/im/pictures/6666b75f-4...     NaN      0.0
# 189    https://a0.muscache.com/im/pictures/e05d4db6-2...     NaN      1.0
# 401                                                  NaN     NaN      3.0
# 497    https://a0.muscache.com/im/pictures/b143c05f-d...     NaN      1.0
# ...                                                  ...     ...      ...
# 73642                                                NaN     NaN      1.0
# 73763  https://a0.muscache.com/im/pictures/ad7476d7-4...     NaN      1.0
# 73925  https://a0.muscache.com/im/pictures/150c7a64-b...     NaN      2.0
# 74060  https://a0.muscache.com/im/pictures/e4f7eb56-a...     NaN      1.0
# 74083  https://a0.muscache.com/im/pictures/c76fa898-4...     NaN      1.0
#
#       beds  int_price
# 26     1.0       95.0
# 96     1.0       70.0
# 189    1.0      125.0
# 401    3.0     1938.0
# 497    2.0       49.0
# ...    ...        ...
# 73642  1.0       43.0
# 73763  1.0       65.0
# 73925  3.0      150.0
# 74060  1.0      160.0
# 74083  1.0      150.0
#
# [966 rows x 30 columns]

# %%
bnb_df1['zipcode'].astype(str).iloc[26]
# Out:
# 'nan'

# %%
# FIND ALL ZIPCODES WITH MISSING VALUES AND SET THEM TO 0 
# change datatype back to object
bnb_df1['zipcode'] = bnb_df1['zipcode'].astype(str)
bnb_df1.loc[(bnb_df1['zipcode'] == ' ') |
            (bnb_df1['zipcode'] == "nan"),'zipcode'] = 0

# %%
display(bnb_df1.loc[bnb_df1['zipcode'] == 0].head())
display(bnb_df1.loc[bnb_df1['zipcode'] == 0].tail())
# Out:
#            id  log_price property_type        room_type  \
# 26   19407360   4.553877     Apartment  Entire home/apt
# 96    4576821   4.248495     Apartment  Entire home/apt
# 189   7144212   4.828314     Apartment     Private room
# 340   5586306   4.499810     Apartment     Private room
# 401  19839317   7.569412         Villa  Entire home/apt
#
#                                              amenities  accommodates  \
# 26   {TV,"Wireless Internet",Pool,Kitchen,"Elevator...             2
# 96   {"Wireless Internet",Kitchen,Breakfast,Elevato...             1
# 189  {TV,"Cable TV",Internet,"Wireless Internet","A...             1
# 340  {TV,Internet,"Wireless Internet","Air conditio...             4
# 401  {TV,"Cable TV",Internet,"Wireless Internet","A...             8
#
#      bathrooms  bed_type cancellation_policy  cleaning_fee  ...   longitude  \
# 26         1.0  Real Bed            flexible          True  ... -118.364204
# 96         1.0  Real Bed            flexible          True  ...  -73.977079
# 189        1.0  Real Bed              strict          True  ...  -74.007225
# 340        1.0  Real Bed            moderate         False  ...  -76.994113
# 401        3.5  Real Bed     super_strict_60          True  ... -118.373981
#
#                                       name       neighbourhood  \
# 26     Retro West Hollywood Studio + Pool!                 NaN
# 96           Charming Studio in Park Slope          Park Slope
# 189  Private room in Amazing Lux building!  Financial District
# 340      Stylish one bedroom+ near redline                 NaN
# 401                  Modern Luxury: 116852                 NaN
#
#     number_of_reviews review_scores_rating  \
# 26                  1                100.0
# 96                  2                100.0
# 189                 3                100.0
# 340                98                 94.0
# 401                 1                100.0
#
#                                          thumbnail_url zipcode bedrooms beds  \
# 26   https://a0.muscache.com/im/pictures/c67ecdec-a...       0      1.0  1.0
# 96   https://a0.muscache.com/im/pictures/6666b75f-4...       0      0.0  1.0
# 189  https://a0.muscache.com/im/pictures/e05d4db6-2...       0      1.0  1.0
# 340  https://a0.muscache.com/im/pictures/b7049541-c...       0      1.0  1.0
# 401                                                NaN       0      3.0  3.0
#
#      int_price
# 26        95.0
# 96        70.0
# 189      125.0
# 340       90.0
# 401     1938.0
#
# [5 rows x 30 columns]
#              id  log_price property_type        room_type  \
# 73642  13465498   3.761200     Apartment     Private room
# 73763  17300316   4.174387         House     Private room
# 73925  10575811   5.010635         House  Entire home/apt
# 74060  19102281   5.075174     Apartment     Private room
# 74083  15423281   5.010635     Apartment     Private room
#
#                                                amenities  accommodates  \
# 73642  {TV,"Cable TV",Internet,"Wireless Internet","A...             1
# 73763  {TV,"Wireless Internet","Air conditioning",Kit...             2
# 73925  {TV,"Wireless Internet","Air conditioning","Wh...             6
# 74060  {"Wireless Internet","Air conditioning",Kitche...             2
# 74083  {TV,"Wireless Internet",Kitchen,"Smoke detecto...             2
#
#        bathrooms  bed_type cancellation_policy  cleaning_fee  ...   longitude  \
# 73642        1.0  Real Bed              strict         False  ...  -73.911694
# 73763        1.0     Futon            flexible          True  ...  -76.987303
# 73925        1.0  Real Bed            flexible          True  ... -118.150099
# 74060        1.0  Real Bed            moderate          True  ...  -73.986541
# 74083        1.0  Real Bed            flexible         False  ... -122.423192
#
#                                                 name   neighbourhood  \
# 73642       Location Little Marina ( only for girls)         Astoria
# 73763       Private Room! Bike to Share! Cat to Pet!             NaN
# 73925                              Delightful Duplex             NaN
# 74060                     Cosy 1 bdr in Midtown West  Hell's Kitchen
# 74083  Charming bedroom in the heart of Russian Hill    Russian Hill
#
#       number_of_reviews review_scores_rating  \
# 73642                 3                 93.0
# 73763                 1                100.0
# 73925                19                 99.0
# 74060                10                 96.0
# 74083                 0                  NaN
#
#                                            thumbnail_url zipcode bedrooms  \
# 73642                                                NaN       0      1.0
# 73763  https://a0.muscache.com/im/pictures/ad7476d7-4...       0      1.0
# 73925  https://a0.muscache.com/im/pictures/150c7a64-b...       0      2.0
# 74060  https://a0.muscache.com/im/pictures/e4f7eb56-a...       0      1.0
# 74083  https://a0.muscache.com/im/pictures/c76fa898-4...       0      1.0
#
#       beds  int_price
# 73642  1.0       43.0
# 73763  1.0       65.0
# 73925  3.0      150.0
# 74060  1.0      160.0
# 74083  1.0      150.0
#
# [5 rows x 30 columns]

# %%
missing_zipcode_list =bnb_df1.loc[bnb_df1['zipcode'] == 0, 'zipcode'].index.to_list()
missing_zipcode_list[:5]
# Out:
# [26, 96, 189, 340, 401]

# %%
# %%time
empty_list

for i in missing_zipcode_list:
    
    some_lat = bnb_df1.iloc[i]['latitude']
    some_long = bnb_df.iloc[i]['longitude']
    # append the lat,lng values into a list for future reference
    empty_list.append(search.by_coordinates(some_lat,some_long, radius=30, returns=2)[0].zipcode)
    
    # store coordinates in a variable
    coords = search.by_coordinates(some_lat, some_long, radius=30, returns=2)[0].zipcode

    # change missing zipcodes with newly determined value
    bnb_df1['zipcode'][i] = coords
# Out:
# C:\Users\smartestpersonalive\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Wall time: 51 s

# %%
# check if changes are made
bnb_df1.iloc[26]['zipcode']
# Out:
# '90046'

# %%
# check missing data (in percentages)
round((bnb_df.isnull().sum() / len(bnb_df) *100),2)
# Out:
# id                         0.00
# log_price                  0.00
# property_type              0.00
# room_type                  0.00
# amenities                  0.00
# accommodates               0.00
# bathrooms                  0.27
# bed_type                   0.00
# cancellation_policy        0.00
# cleaning_fee               0.00
# city                       0.00
# description                0.00
# first_review              21.41
# host_has_profile_pic       0.25
# host_identity_verified     0.25
# host_response_rate        24.69
# host_since                 0.25
# instant_bookable           0.00
# last_review               21.36
# latitude                   0.00
# longitude                  0.00
# name                       0.00
# neighbourhood              9.27
# number_of_reviews          0.00
# review_scores_rating      22.56
# thumbnail_url             11.09
# zipcode                    1.30
# bedrooms                   0.12
# beds                       0.18
# int_price                  0.00
# dtype: float64

# %%
# change zipcode column back to category datatype
bnb_df1['zipcode'] = bnb_df1['zipcode'].astype('category').cat.as_ordered()

# %% [markdown]
# #### Edit host_response_rate (get rid of percentage sign)

# %%
bnb_df1['host_response_rate'] = bnb_df1['host_response_rate'].str.replace("%", "")

# %%
# change host_response_rate column back to category datatype
bnb_df1['host_response_rate'] = bnb_df1['host_response_rate'].astype("category").cat.as_ordered()

# %% [markdown]
# #### Create a copy

# %%
bnb_df2 = bnb_df1.copy()

# %% [markdown]
# ## Fill missing values
#
# #### Fill numerical missing values
#
# also create a binary column to indicate whether values were missing or not. This is important for feature engineering which is contructing features in the data that don't explicitly exist.

# %%
bnb_df2.dtypes
# Out:
# id                                 int64
# log_price                        float64
# property_type                   category
# room_type                       category
# amenities                       category
# accommodates                       int64
# bathrooms                        float64
# bed_type                        category
# cancellation_policy             category
# cleaning_fee                        bool
# city                            category
# description                     category
# first_review                    category
# host_has_profile_pic            category
# host_identity_verified          category
# host_response_rate              category
# host_since                datetime64[ns]
# instant_bookable                category
# last_review               datetime64[ns]
# latitude                         float64
# longitude                        float64
# name                            category
# neighbourhood                   category
# number_of_reviews                  int64
# review_scores_rating             float64
# thumbnail_url                   category
# zipcode                         category
# bedrooms                         float64
# beds                             float64
# int_price                        float64
# dtype: object

# %%
bnb_df2.head(2).T
# Out:
#                                                                         0  \
# id                                                                6901257
# log_price                                                         5.01064
# property_type                                                   Apartment
# room_type                                                 Entire home/apt
# amenities               {"Wireless Internet","Air conditioning",Kitche...
# accommodates                                                            3
# bathrooms                                                               1
# bed_type                                                         Real Bed
# cancellation_policy                                                strict
# cleaning_fee                                                         True
# city                                                                  NYC
# description             Beautiful, sunlit brownstone 1-bedroom in the ...
# first_review                                                   2016-06-18
# host_has_profile_pic                                                    t
# host_identity_verified                                                  t
# host_response_rate                                                    NaN
# host_since                                            2012-03-26 00:00:00
# instant_bookable                                                        f
# last_review                                           2016-07-18 00:00:00
# latitude                                                          40.6965
# longitude                                                        -73.9916
# name                                       Beautiful brownstone 1-bedroom
# neighbourhood                                            Brooklyn Heights
# number_of_reviews                                                       2
# review_scores_rating                                                  100
# thumbnail_url           https://a0.muscache.com/im/pictures/6d7cbbf7-c...
# zipcode                                                             11201
# bedrooms                                                                1
# beds                                                                    1
# int_price                                                             150
#
#                                                                         1
# id                                                                6304928
# log_price                                                          5.1299
# property_type                                                   Apartment
# room_type                                                 Entire home/apt
# amenities               {"Wireless Internet","Air conditioning",Kitche...
# accommodates                                                            7
# bathrooms                                                               1
# bed_type                                                         Real Bed
# cancellation_policy                                                strict
# cleaning_fee                                                         True
# city                                                                  NYC
# description             Enjoy travelling during your stay in Manhattan...
# first_review                                                   2017-08-05
# host_has_profile_pic                                                    t
# host_identity_verified                                                  f
# host_response_rate                                                    100
# host_since                                            2017-06-19 00:00:00
# instant_bookable                                                        t
# last_review                                           2017-09-23 00:00:00
# latitude                                                          40.7661
# longitude                                                         -73.989
# name                             Superb 3BR Apt Located Near Times Square
# neighbourhood                                              Hell's Kitchen
# number_of_reviews                                                       6
# review_scores_rating                                                   93
# thumbnail_url           https://a0.muscache.com/im/pictures/348a55fe-4...
# zipcode                                                             10019
# bedrooms                                                                3
# beds                                                                    3
# int_price                                                             169

# %%
# if dtype is numeric then print the "labels"
for label, content in bnb_df2.items():
    if pd.api.types.is_numeric_dtype(bnb_df2[label]):
        if bnb_df2[label].isnull().sum() > 0:
            # add a vinary column that tells us if the data was missing
            bnb_df2[f"{label}_is_missing"] = pd.isnull(bnb_df2[label])
            # Fill missing numeric values with median
            bnb_df2[label] = bnb_df2[label].fillna(bnb_df2[label].median())
            
            # print columns with null values (which columns were the changes made on)
            print(label)
# Out:
# bathrooms
# review_scores_rating
# bedrooms
# beds

# %%
# check to see if there are still any null numeric values (should output nothing
for label, content in bnb_df2.items():
    if pd.api.types.is_numeric_dtype(bnb_df2[label]):
        if bnb_df2[label].isnull().sum() > 0:
            print(label)

# %%
bnb_df2.columns
# Out:
# Index(['id', 'log_price', 'property_type', 'room_type', 'amenities',
#        'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy',
#        'cleaning_fee', 'city', 'description', 'first_review',
#        'host_has_profile_pic', 'host_identity_verified', 'host_response_rate',
#        'host_since', 'instant_bookable', 'last_review', 'latitude',
#        'longitude', 'name', 'neighbourhood', 'number_of_reviews',
#        'review_scores_rating', 'thumbnail_url', 'zipcode', 'bedrooms', 'beds',
#        'int_price', 'bathrooms_is_missing', 'review_scores_rating_is_missing',
#        'bedrooms_is_missing', 'beds_is_missing'],
#       dtype='object')

# %%
bnb_df2['review_scores_rating_is_missing'].value_counts()
# Out:
# False    57389
# True     16722
# Name: review_scores_rating_is_missing, dtype: int64

# %%
# still have missing values in the dataset
bnb_df2.isnull().sum()
# Out:
# id                                     0
# log_price                              0
# property_type                          0
# room_type                              0
# amenities                              0
# accommodates                           0
# bathrooms                              0
# bed_type                               0
# cancellation_policy                    0
# cleaning_fee                           0
# city                                   0
# description                            0
# first_review                       15864
# host_has_profile_pic                 188
# host_identity_verified               188
# host_response_rate                 18299
# host_since                           188
# instant_bookable                       0
# last_review                        15827
# latitude                               0
# longitude                              0
# name                                   0
# neighbourhood                       6872
# number_of_reviews                      0
# review_scores_rating                   0
# thumbnail_url                       8216
# zipcode                                0
# bedrooms                               0
# beds                                   0
# int_price                              0
# bathrooms_is_missing                   0
# review_scores_rating_is_missing        0
# bedrooms_is_missing                    0
# beds_is_missing                        0
# dtype: int64

# %%
bnb_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 34 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               74111 non-null  int64
#  1   log_price                        74111 non-null  float64
#  2   property_type                    74111 non-null  category
#  3   room_type                        74111 non-null  category
#  4   amenities                        74111 non-null  category
#  5   accommodates                     74111 non-null  int64
#  6   bathrooms                        74111 non-null  float64
#  7   bed_type                         74111 non-null  category
#  8   cancellation_policy              74111 non-null  category
#  9   cleaning_fee                     74111 non-null  bool
#  10  city                             74111 non-null  category
#  11  description                      74111 non-null  category
#  12  first_review                     58247 non-null  category
#  13  host_has_profile_pic             73923 non-null  category
#  14  host_identity_verified           73923 non-null  category
#  15  host_response_rate               55812 non-null  category
#  16  host_since                       73923 non-null  datetime64[ns]
#  17  instant_bookable                 74111 non-null  category
#  18  last_review                      58284 non-null  datetime64[ns]
#  19  latitude                         74111 non-null  float64
#  20  longitude                        74111 non-null  float64
#  21  name                             74111 non-null  category
#  22  neighbourhood                    67239 non-null  category
#  23  number_of_reviews                74111 non-null  int64
#  24  review_scores_rating             74111 non-null  float64
#  25  thumbnail_url                    65895 non-null  category
#  26  zipcode                          74111 non-null  category
#  27  bedrooms                         74111 non-null  float64
#  28  beds                             74111 non-null  float64
#  29  int_price                        74111 non-null  float64
#  30  bathrooms_is_missing             74111 non-null  bool
#  31  review_scores_rating_is_missing  74111 non-null  bool
#  32  bedrooms_is_missing              74111 non-null  bool
#  33  beds_is_missing                  74111 non-null  bool
# dtypes: bool(5), category(16), datetime64[ns](2), float64(8), int64(3)
# memory usage: 22.2 MB

# %%
pd.Categorical(bnb_df1['property_type']).codes
# Out:
# array([0, 0, 0, ..., 0, 0, 2], dtype=int8)

# %%
# select the cateogircal columns (select if not numeric)
for label, content, in bnb_df2.items():
    if not pd.api.types.is_numeric_dtype(bnb_df2[label]):
        # add a binary column to indicate whether sample has missing value
        bnb_df2[f"{label}_is_missing"] = pd.isnull(bnb_df2[label])
        # turn categories into numbers and add +1
        bnb_df2[label] = pd.Categorical(content).codes + 1
        # show cateogircal labels:
        print(label)
# Out:
# property_type
# room_type
# amenities
# bed_type
# cancellation_policy
# city
# description
# first_review
# host_has_profile_pic
# host_identity_verified
# host_response_rate
# host_since
# instant_bookable
# last_review
# name
# neighbourhood
# thumbnail_url
# zipcode

# %%
bnb_df1.head(2).T
# Out:
#                                                                         0  \
# id                                                                6901257
# log_price                                                         5.01064
# property_type                                                   Apartment
# room_type                                                 Entire home/apt
# amenities               {"Wireless Internet","Air conditioning",Kitche...
# accommodates                                                            3
# bathrooms                                                               1
# bed_type                                                         Real Bed
# cancellation_policy                                                strict
# cleaning_fee                                                         True
# city                                                                  NYC
# description             Beautiful, sunlit brownstone 1-bedroom in the ...
# first_review                                                   2016-06-18
# host_has_profile_pic                                                    t
# host_identity_verified                                                  t
# host_response_rate                                                    NaN
# host_since                                            2012-03-26 00:00:00
# instant_bookable                                                        f
# last_review                                           2016-07-18 00:00:00
# latitude                                                          40.6965
# longitude                                                        -73.9916
# name                                       Beautiful brownstone 1-bedroom
# neighbourhood                                            Brooklyn Heights
# number_of_reviews                                                       2
# review_scores_rating                                                  100
# thumbnail_url           https://a0.muscache.com/im/pictures/6d7cbbf7-c...
# zipcode                                                             11201
# bedrooms                                                                1
# beds                                                                    1
# int_price                                                             150
#
#                                                                         1
# id                                                                6304928
# log_price                                                          5.1299
# property_type                                                   Apartment
# room_type                                                 Entire home/apt
# amenities               {"Wireless Internet","Air conditioning",Kitche...
# accommodates                                                            7
# bathrooms                                                               1
# bed_type                                                         Real Bed
# cancellation_policy                                                strict
# cleaning_fee                                                         True
# city                                                                  NYC
# description             Enjoy travelling during your stay in Manhattan...
# first_review                                                   2017-08-05
# host_has_profile_pic                                                    t
# host_identity_verified                                                  f
# host_response_rate                                                    100
# host_since                                            2017-06-19 00:00:00
# instant_bookable                                                        t
# last_review                                           2017-09-23 00:00:00
# latitude                                                          40.7661
# longitude                                                         -73.989
# name                             Superb 3BR Apt Located Near Times Square
# neighbourhood                                              Hell's Kitchen
# number_of_reviews                                                       6
# review_scores_rating                                                   93
# thumbnail_url           https://a0.muscache.com/im/pictures/348a55fe-4...
# zipcode                                                             10019
# bedrooms                                                                3
# beds                                                                    3
# int_price                                                             169

# %%
# check for missing values now
bnb_df2.isnull().sum()
# Out:
# id                                   0
# log_price                            0
# property_type                        0
# room_type                            0
# amenities                            0
# accommodates                         0
# bathrooms                            0
# bed_type                             0
# cancellation_policy                  0
# cleaning_fee                         0
# city                                 0
# description                          0
# first_review                         0
# host_has_profile_pic                 0
# host_identity_verified               0
# host_response_rate                   0
# host_since                           0
# instant_bookable                     0
# last_review                          0
# latitude                             0
# longitude                            0
# name                                 0
# neighbourhood                        0
# number_of_reviews                    0
# review_scores_rating                 0
# thumbnail_url                        0
# zipcode                              0
# bedrooms                             0
# beds                                 0
# int_price                            0
# bathrooms_is_missing                 0
# review_scores_rating_is_missing      0
# bedrooms_is_missing                  0
# beds_is_missing                      0
# property_type_is_missing             0
# room_type_is_missing                 0
# amenities_is_missing                 0
# bed_type_is_missing                  0
# cancellation_policy_is_missing       0
# city_is_missing                      0
# description_is_missing               0
# first_review_is_missing              0
# host_has_profile_pic_is_missing      0
# host_identity_verified_is_missing    0
# host_response_rate_is_missing        0
# host_since_is_missing                0
# instant_bookable_is_missing          0
# last_review_is_missing               0
# name_is_missing                      0
# neighbourhood_is_missing             0
# thumbnail_url_is_missing             0
# zipcode_is_missing                   0
# dtype: int64

# %%
# change column (host_response_rate) to host_response_rate_pct
bnb_df2.rename(columns={"host_response_rate":"host_response_rate_pct"}, inplace=True)

# %%
bnb_df2.shape
# Out:
# (74111, 52)

# %% [markdown]
# ## Build machine learning model (Regression)
# build a ML model now that missing data are taken care of
#
# Find patterns in the data to predict the price

# %%
bnb_df2.head(2)
# Out:
#         id  log_price  property_type  room_type  amenities  accommodates  \
# 0  6901257   5.010635              1          1       6143             3
# 1  6304928   5.129899              1          1       6270             7
#
#    bathrooms  bed_type  cancellation_policy  cleaning_fee  ...  \
# 0        1.0         5                    3          True  ...
# 1        1.0         5                    3          True  ...
#
#    host_has_profile_pic_is_missing  host_identity_verified_is_missing  \
# 0                            False                              False
# 1                            False                              False
#
#    host_response_rate_is_missing  host_since_is_missing  \
# 0                           True                  False
# 1                          False                  False
#
#    instant_bookable_is_missing  last_review_is_missing  name_is_missing  \
# 0                        False                   False            False
# 1                        False                   False            False
#
#    neighbourhood_is_missing  thumbnail_url_is_missing  zipcode_is_missing
# 0                     False                     False               False
# 1                     False                     False               False
#
# [2 rows x 52 columns]

# %%
# use predefined function to create heatmap
sns_corr_heatmap(bnb_df2.iloc[:,:30])

# %%
sns_corr_heatmap(bnb_df2.iloc[:, 15:30])

# %%
bnb_df2.columns.tolist().index("bathrooms_is_missing")
# Out:
# 30

# %%
bnb_df2.iloc[:,:30].head()
# Out:
#          id  log_price  property_type  room_type  amenities  accommodates  \
# 0   6901257   5.010635              1          1       6143             3
# 1   6304928   5.129899              1          1       6270             7
# 2   7919400   4.976734              1          1      21346             5
# 3  13418779   6.620073             18          1      38855             4
# 4   3808709   4.744932              1          1      55414             2
#
#    bathrooms  bed_type  cancellation_policy  cleaning_fee  ...   longitude  \
# 0        1.0         5                    3          True  ...  -73.991617
# 1        1.0         5                    3          True  ...  -73.989040
# 2        1.0         5                    2          True  ...  -73.943756
# 3        1.0         5                    1          True  ... -122.431619
# 4        1.0         5                    2          True  ...  -77.034596
#
#     name  neighbourhood  number_of_reviews  review_scores_rating  \
# 0  10465             78                  2                 100.0
# 1  65673            253                  6                  93.0
# 2  66397            248                 10                  92.0
# 3   9388            326                  0                  96.0
# 4  32069            120                  4                  40.0
#
#    thumbnail_url  zipcode  bedrooms  beds  int_price
# 0          32399      202       1.0   1.0      150.0
# 1          16221       74       3.0   3.0      169.0
# 2          32853       85       1.0   3.0      145.0
# 3          33693      762       2.0   2.0      750.0
# 4              0      350       0.0   1.0      115.0
#
# [5 rows x 30 columns]

# %%
bnb_df2.columns.tolist()
# Out:
# ['id',
#  'log_price',
#  'property_type',
#  'room_type',
#  'amenities',
#  'accommodates',
#  'bathrooms',
#  'bed_type',
#  'cancellation_policy',
#  'cleaning_fee',
#  'city',
#  'description',
#  'first_review',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'host_response_rate_pct',
#  'host_since',
#  'instant_bookable',
#  'last_review',
#  'latitude',
#  'longitude',
#  'name',
#  'neighbourhood',
#  'number_of_reviews',
#  'review_scores_rating',
#  'thumbnail_url',
#  'zipcode',
#  'bedrooms',
#  'beds',
#  'int_price',
#  'bathrooms_is_missing',
#  'review_scores_rating_is_missing',
#  'bedrooms_is_missing',
#  'beds_is_missing',
#  'property_type_is_missing',
#  'room_type_is_missing',
#  'amenities_is_missing',
#  'bed_type_is_missing',
#  'cancellation_policy_is_missing',
#  'city_is_missing',
#  'description_is_missing',
#  'first_review_is_missing',
#  'host_has_profile_pic_is_missing',
#  'host_identity_verified_is_missing',
#  'host_response_rate_is_missing',
#  'host_since_is_missing',
#  'instant_bookable_is_missing',
#  'last_review_is_missing',
#  'name_is_missing',
#  'neighbourhood_is_missing',
#  'thumbnail_url_is_missing',
#  'zipcode_is_missing']

# %% [markdown]
# #### Try the ridge regression model

# %%
# just ignore int_price for now
bnb_df2.drop('int_price', axis=1, inplace=True)

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split


# setup random seed
np.random.seed(42)

# Create the data
X = bnb_df2.drop('log_price', axis=1)
y = bnb_df2['log_price']

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)


# Instantiate Ridge model
model = Ridge()
model.fit(X_train,y_train)

# Check the score of the Ridge model on test data
model.score(X_test,y_test)
# Out:
# C:\Users\smartestpersonalive\Anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=4.55174e-19): result may not be accurate.
#   overwrite_a=True).T
# 0.5614262315567364

# %% [markdown]
# #### Try Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# Set up Random seed
np.random.seed(42)

# Instantiate Random Forest Regressor
rf = RandomForestRegressor()
rf.fit(X_train, y_train)

# Evaluate the Random Forest Regressor
rf.score(X_test,y_test)
# Out:
# 0.7035600680335106

# %% [markdown]
# without doing any hyperparameter tuning, randomForestRegressor already improved the model

# %% [markdown]
# ## making predictions using a machine learning model
